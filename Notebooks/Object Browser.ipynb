# %% [markdown]
# ### In this notebook I'll explain with more detail what are some of the main branches for our calibration purposes.

# %%
# REQUIRED PACKAGES
import ROOT
from ROOT import RDataFrame
import numpy as np

# IMPORTING ADDITIONAL PACKAGES
from ipywidgets import interact, widgets
import dunestyle.root as dunestyle
# Out:
# Welcome to JupyROOT 6.22/08
# DUNE plot style enabled

# %%
# READING FILE TREES
file = ROOT.TFile.Open('../../nearlinetest/Iterations/ntuple_cal.root')
key_list = file.GetListOfKeys()
trees = []
for key in key_list:
    # Get the object associated with the key
    obj = key.ReadObj()
    # Check if the object is a TTree
    if isinstance(obj, ROOT.TTree):
        # Append the name of the tree to the array
        trees.append(obj.GetName())

trees.insert(0, 'Select Tree')
drop_down_trees = widgets.Dropdown(options=trees,
                                description='🌴 Tree:',
                                disabled=False,
                                layout={'width': 'max-content'})
display(drop_down_trees)
# Out:
# Dropdown(description='🌴 Tree:', layout=Layout(width='max-content'), options=('Select Tree', 'header', 'gates',…

# %%
tree = file.Get(drop_down_trees.value)
canvas = ROOT.TCanvas("canvas", "Plot")

# %%
# EXTRACTING DATA FROM SELECTED TREE
list = tree.GetListOfBranches()
branches = []
for item in list:
    # Get the name of the branch
    branch_name = item.GetName()
    # Append the name to the array
    branches.append(branch_name)

branches.insert(0, 'Select Branch')
drop_down_branches = widgets.Dropdown(options=branches,
                            description='🍂 Branch:',
                            disabled=False,
                            layout={'width': 'max-content'})
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', layout=Layout(width='max-content'), options=('Select Branch', 'ev_run', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# ev: Means event. One event in this file is one muon.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=3, layout=Layout(width='max-content'), options=('Select Branch', 'ev_r…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# First peak: Tracks that only go to the front.
#
# Second peak: Tracks that only go to the back.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=44, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# In the HCAL there is only one plane for each module, so we can roughly half as many hits. In the rest of the detector we have two planes for every modules, that's why we have that little dip.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=45, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# We can see plane 1 and plane 2. In the HCAL the scintillator is plane 2.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=46, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# We get peaks at the edges, why? This is just strip number.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=47, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Energy deposited in the strip in MeV.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=50, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Reconstructed track path length in the strip. Spike at zero are associated with hits that are associated with the track, but when the track doesn't necessarily pass trough those strips. This path variable is in mm. The flat distribution from 0 to 1.7 cm is basically the width is what we expect to see. This is relevant for the alignment when we are looking for the path correction.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=51, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# The ones than don't go to anything are coded to -99. This is the triangle, zero means that the track enters the strip right in the center. +17 and -17 cm are just the rest of the triangle. For doing the alignment we are going to compare the normal incidence corrected path that takes into account the path and base position and the correct it for normal incidence, and compare it to energy. You should see a triangle that peaks at zero.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=52, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Position along the strip. Positive lpos is always the readout end? so there are more hits on the readout side? I'd expect this to be not exactly flat because some strips have different shapes. We are not sure why is not symmetric.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=53, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Strip to strip constant, always one. This is used for alignment and strip to strip calibration.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=61, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Maybe the 12 front planes give you the first 24 clusters. If a track has a cluster at every plane in the front 4 module sets that would be 24. This is probably lower priority.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=62, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Basically the same as strips but just only the hits around the muon.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=80, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# rt: raw time

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=87, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# ct: corrected time

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=88, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Time of flight in ns from the start of the track to a hit. We can see it takes 4 ns to take for the 4 planes, then 10 ns to go through the gap, and the 20 ns to the gap.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=89, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# dtc: distance to conector

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=90, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# dtm: distance to mirror. The position of the hit within the strip

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=91, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# bfl: baggy fiber length? Depending on what strip you are in there are different lengths between the edge on the plane and the readouts.

# %%
display(drop_down_branches)
# Out:
# Dropdown(description='🍂 Branch:', index=93, layout=Layout(width='max-content'), options=('Select Branch', 'ev_…

# %%
# PLOTTING HISTOGRAM
tree.Draw(drop_down_branches.value)
canvas.Draw()

# %% [markdown]
# Clear fiber.
